# %% [markdown]
# # 1. استكشاف البيانات الأساسية

# %%
from pyspark.sql import SparkSessionspark = SparkSession.builder.appName('DataExploration').getOrCreate()df = spark.read.csv('../data/yellow_tripdata_2016-03.csv', header=True, inferSchema=True)

# %%
df.printSchema()

# %%
df.show(5)

# %%
df.describe().show()
